# %%
# imports
import conllu
from sklearn.naive_bayes import MultinomialNB
import numpy as np
from ordered_set import OrderedSet
from tqdm import tqdm
from sklearn.metrics import classification_report

# %%
# load the conllu dataset
with open("../data/dataset.conllu") as f:
    data = conllu.parse(f.read())

# %%
# extract headlines (since a headline can have more than one sentence)
headlines = []
for i, sentence in enumerate(data):
    if sentence.metadata["sent_id"] == "0":
        headlines.append(data[i:i+1])
    else:
        headlines[-1].append(sentence)
print(len(headlines))
# Out:
# 28619

# %%
# gather all features (i.e. all tokens)
features = OrderedSet()
for headline in headlines:
    for sentence in headline:
        for token in sentence:
            features |= [token["lemma"]]
print(len(features))
print(features)
# Out:
# 21280
# OrderedSet(['thirtysomethe', 'scientist', 'unveil', 'doomsday', 'clock', 'of', 'hair', 'loss', 'dem', 'rep', '.', 'totally', 'nail', 'why', 'congress', 'be', 'fall', 'short', 'on', 'gender', ',', 'racial', 'equality', 'eat', 'your', 'veggie', ':', '9', 'deliciously', 'different', 'recipe', 'inclement', 'weather', 'prevent', 'liar', 'from', 'get', 'to', 'work', 'mother', 'come', 'pretty', 'close', 'use', 'word', "'", 'streaming', 'correctly', 'my', 'white', 'inheritance', '5', 'way', 'file', 'taxis', 'with', 'less', 'stress', 'richard', 'branson', "'s", 'global', '-', 'warm', 'donation', 'nearly', 'as', 'much', 'cost', 'fail', 'balloon', 'trip', 'shadow', 'government', 'too', 'large', 'meet', 'in', 'marriott', 'conference', 'room', 'b', 'lot', 'parent', 'know', 'this', 'scenario', 'lesbian', 'consider', 'a', 'father', 'indiana', '(', 'and', 'an', 'amazing', 'one', 'at', 'that', ')', 'amanda', 'peet', 'tell', 'her', 'daughter', 'sex', 'special', 'hug', 'what', 'regard', 'current', 'treatment', 'for', 'ebola', 'chris', 'christie', 'suggest', 'hillary', 'clinton', 'blame', 'boko', 'haram', 'kidnapping', 'hundred', 'schoolgirl', 'ford', 'develop', 'new', 'suv', 'run', 'purely', 'gasoline', 'uber', 'ceo', 'travis', 'kalanick', 'step', 'down', 'trump', 'economic', 'advisory', 'council', 'area', 'boy', 'enter', 'jump', 'touching', 'tops', 'doorway', 'phase', 'man', 'do', 'most', 'his', 'travel', 'by', 'gurney', 'leave', 'no', 'person', 'disability', 'behind', 'lin', 'manuel', 'miranda', 'would', 'like', 'remind', 'you', 'put', 'phone', 'away', '60', 'journalist', 'kill', '2014', 'target', 'international', 'press', 'rise', 'guard', 'video', 'game', 'under', 'strict', 'order', 'repeatedly', 'pace', 'same', 'stretch', 'hallway', 'how', 'live', '110', 'cat', 'so', 'scared', 'shelter', 'will', 'not', 'even', 'look', 'bill', 'shoot', 'republicans', 'I', 'strongly', 'support', 'obamacare', 'secret', 'service', 'agent', 'about', 'david', 'alan', 'grier', 'fan', 'orange', 'era', 'the', 'grow', 'divide', 'thing', 'learn', 'first', 'month', 'have', 'baby', 'lamelo', 'ball', 'score', '92', 'point', 'single', 'high', 'school', 'basketball', 'bi', 'it', 'take', '21', 'year', 'out', 'closet', 'say', '10', 'essential', 'life', 'lesson', 'grandma', 'teenage', 'gunfight', 'isis', 'old', 'but', 'still', 'young', 'heart', 'lead', 'probability', 'researcher', 'confound', 'three', 'coworker', 'wear', 'shirt', 'color', 'day', 'york', 'introduce', 'shoe', 'share', 'program', 'city', 'pedestrian', 'beyoncé', 'sculpt', 'cheese', 'strangely', 'alluring', 'expansive', 'obama', 'state', 'union', 'speech', 'touch', 'patent', 'law', 'entomology', 'film', 'robert', 'altman', 'star', 'gray', 'prove', 'all', 'bad', 'police', 'woman', 'make', 'up', 'story', 'attack', 'two', 'hat', 'update', 'naacp', 'demand', 'minority', 'representation', 'upn', 'good', 'clothe', 'child', 'florist', 'who', 'turn', 'gay', 'couple', 'want', 'supreme', 'court', 'hear', 'case', 'we', 'process', 'end', 'walk', 'dead', '"', 'stranger', 'google', 'project', 'deliver', 'critical', 'info', 'refugee', 'smartphone', 'history', 'textbook', 'hatred', 'alive', 'student', 'ridiculously', 'successful', 'people', 'think', 'differently', 'report', 'bridge', 'probably', 'whole', 'mess', 'bat', 'there', 'texas', 'urge', 'style', 'immigration', 'crackdown', 'tom', 'hank', 'brag', 'smokin', 'hot', 'rita', 'wilson', 'after', '29', 'marriage', 'god', 'strong', 'bring', 'back', 'dinosaur', 'lgbt', 'christians', 'speak', 'love', 'sinner', 'hate', 'sin', 'cut', 'anymore', 'handshake', 'unusually', 'angle', 'velocity', 'mom', 'keep', 'send', 'newspaper', 'clipping', 'former', 'classmate', 'murder', 'stop', 'coed', 'rec', 'softball', 'team', 'trouble', 'find', 'enough', 'hyper', 'competitive', 'ruin', 'experience', 'brutalist', 'beaver', 'construct', 'paul', 'rudolph', 'inspire', 'dam', 'jindal', 'westboro', 'baptist', 'member', 'protest', 'funeral', 'face', 'arrest', 'gop', 'congressman', 'may', 'vote', 'presiden ...

# %%
# create the Bag of Words model
bow = MultinomialNB()
classes = [0, 1]

# fit the model to the data
for headline in tqdm(headlines):
    X = np.zeros(len(features))
    y = np.array([int(headline[0].metadata["class"])])
    for sentence in headline:
        for token in sentence:
            X[features.index(token["lemma"])] += 1
    bow.partial_fit(X.reshape(1, -1), y, classes)
# Out:
# 100%|██████████| 28619/28619 [00:26<00:00, 1085.74it/s]

# %%
# test some headlines
y_true = []
y_pred = []
for headline in tqdm(headlines):
    X = np.zeros(len(features))
    y = np.array([int(headline[0].metadata["class"])])
    for sentence in headline:
        for token in sentence:
            X[features.index(token["lemma"])] += 1
    y_pred.append(bow.predict(X.reshape(1, -1))[0])
    y_true.append(y[0])
target_names = ['Non-sarcastic', 'Sarcastic']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# 100%|██████████| 28619/28619 [00:03<00:00, 7917.50it/s]
#                precision    recall  f1-score   support
#
# Non-sarcastic       0.91      0.93      0.92     14985
#     Sarcastic       0.92      0.90      0.91     13634
#
#      accuracy                           0.91     28619
#     macro avg       0.91      0.91      0.91     28619
#  weighted avg       0.91      0.91      0.91     28619
